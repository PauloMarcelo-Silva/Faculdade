# %%
import pandas as pd
import numpy as np
import math as mt
import scipy as sp
import matplotlib.pyplot as plt
import seaborn as sns
TwUsers = pd.read_csv('Twitch_user_data.csv')
TwUsers
# Out:
#               Channel  Watch time(Minutes)  Stream time(minutes)  \
# 0               xQcOW           6196161750                215250
# 1            summit1g           6091677300                211845
# 2              Gaules           5644590915                515280
# 3            ESL_CSGO           3970318140                517740
# 4                Tfue           3671000070                123660
# ..                ...                  ...                   ...
# 995         LITkillah            122524635                 13560
# 996  빅헤드 (bighead033)            122523705                153000
# 997    마스카 (newmasca)            122452320                217410
# 998     AndyMilonakis            122311065                104745
# 999              Remx            122192850                 99180
#
#      Peak viewers  Average viewers  Followers  Followers gained  Views gained  \
# 0          222720            27716    3246298           1734810      93036735
# ...

# %%
TwUsers[TwUsers["Watch time(Minutes)"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers[TwUsers["Stream time(minutes)"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers[TwUsers["Peak viewers"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers[TwUsers["Average viewers"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers[TwUsers["Followers"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers[TwUsers["Followers gained"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers[TwUsers["Views gained"].isnull()]
# Out:
# Empty DataFrame
# Columns: [Channel, Watch time(Minutes), Stream time(minutes), Peak viewers, Average viewers, Followers, Followers gained, Views gained, Partnered, Mature, Language]
# Index: []

# %%
TwUsers.isnull()
# Out:
#      Channel  Watch time(Minutes)  Stream time(minutes)  Peak viewers  \
# 0      False                False                 False         False
# 1      False                False                 False         False
# 2      False                False                 False         False
# 3      False                False                 False         False
# 4      False                False                 False         False
# ..       ...                  ...                   ...           ...
# 995    False                False                 False         False
# 996    False                False                 False         False
# 997    False                False                 False         False
# 998    False                False                 False         False
# 999    False                False                 False         False
#
#      Average viewers  Followers  Followers gained  Views gained  Partnered  \
# ...
