# %%
import pandas as pd
import numpy as np
import math as mt
import statistics as st
import matplotlib.pyplot as plt
import seaborn as sns
TwGames = pd.read_csv('Twitch_game_data.csv')
TwGames
# Out:
#                                    Game  Rank  Month  Year  Hours_watched  \
# 0                     League of Legends     1      1  2016       94377226
# 1      Counter-Strike: Global Offensive     2      1  2016       47832863
# 2                                Dota 2     3      1  2016       45185893
# 3                           Hearthstone     4      1  2016       39936159
# 4           Call of Duty: Black Ops III     5      1  2016       16153057
# ...                                 ...   ...    ...   ...            ...
# 12345                            Visage   196     12  2020         524013
# 12346                           Outlast   197     12  2020         519209
# 12347                   Call of the Sea   198     12  2020         515643
# 12348                        Fallout 76   199     12  2020         515422
# 12349         Lineage: The Blood Pledge   200     12  2020         513380
#
#        Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
TwGames.astype({"Avg_viewer_ratio":  int})
# Out:
#                                    Game  Rank  Month  Year  Hours_watched  \
# 0                     League of Legends     1      1  2016       94377226
# 1      Counter-Strike: Global Offensive     2      1  2016       47832863
# 2                                Dota 2     3      1  2016       45185893
# 3                           Hearthstone     4      1  2016       39936159
# 4           Call of Duty: Black Ops III     5      1  2016       16153057
# ...                                 ...   ...    ...   ...            ...
# 12345                            Visage   196     12  2020         524013
# 12346                           Outlast   197     12  2020         519209
# 12347                   Call of the Sea   198     12  2020         515643
# 12348                        Fallout 76   199     12  2020         515422
# 12349         Lineage: The Blood Pledge   200     12  2020         513380
#
#        Hours_Streamed  Peak_viewers  Peak_channels  Streamers  Avg_viewers  \
# ...

# %%
TwGames.isnull()
# Out:
#         Game   Rank  Month   Year  Hours_watched  Hours_Streamed  \
# 0      False  False  False  False          False           False
# 1      False  False  False  False          False           False
# 2      False  False  False  False          False           False
# 3      False  False  False  False          False           False
# 4      False  False  False  False          False           False
# ...      ...    ...    ...    ...            ...             ...
# 12345  False  False  False  False          False           False
# 12346  False  False  False  False          False           False
# 12347  False  False  False  False          False           False
# 12348  False  False  False  False          False           False
# 12349  False  False  False  False          False           False
#
#        Peak_viewers  Peak_channels  Streamers  Avg_viewers  Avg_channels  \
# 0             False          False      False        False         False
# ...
